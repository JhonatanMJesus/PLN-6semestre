# %% [markdown]
# ### Considere o seguinte conjunto de documentos:
# ➢doc1 = "o gato dorme no sofá"
#
# ➢doc2 = "o cachorro dorme no tapete"
#
# ➢doc3 = "o gato caça o rato"
#
# ➢doc4 = "o cachorro corre no parque"
#
# Utilizando TF-IDF, faça o seguinte:
#
# a) Crie uma lista com os documentos.
#
# b) Utilize TfidfVectorizer para transformar os textos em uma matriz TF-IDF.
#
# c) Exiba: a matriz resultante e as palavras (features) extraídas do corpus
#
# d) Identifique manualmente quais palavras possuem maior peso em cada documento
#
# e) Explique por que palavras como "o" possuem peso baixo.
