# %%
# %pip install gensim
# Out:
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.2 kB ? eta -:--:--
#      -------------------------------------- 61.2/61.2 kB 808.3 kB/s eta 0:00:00
# ...
#   Using cached smart_open-8.0.1-py3-none-any.whl.metadata (24 kB)
# ...
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    ---------------------------------------- 0.1/24.4 MB 2.4 MB/s eta 0:00:11
#     --------------------------------------- 0.3/24.4 MB 3.3 MB/s eta 0:00:08
#     --------------------------------------- 0.5/24.4 MB 3.7 MB/s eta 0:00:07
#    - -------------------------------------- 0.8/24.4 MB 4.1 MB/s eta 0:00:06
#    - -------------------------------------- 1.1/24.4 MB 4.6 MB/s eta 0:00:06
#    -- ------------------------------------- 1.4/24.4 MB 4.9 MB/s eta 0:00:05
#    -- ------------------------------------- 1.7/24.4 MB 5.2 MB/s eta 0:00:05
# ...

# %%
from gensim.models import Word2Vec

sentences = [
    ["gato", "come", "peixe"],
    ["cachorro", "come", "carne"],
    ["gato", "e", "cachorro", "são", "animais"]
]

# Treinando o modelo
# vector_size: tamanho do vetor (embedding)
# window: janela de contexto
# min_count: ignora palavras que aparecem menos que x vezes
model = Word2Vec(sentences, vector_size=5, window=2, min_count=1)

print(model.wv['gato'])  # Vetor de embedding para a palavra "gato"
# Out:
# [ 0.1476101  -0.03066943 -0.09073226  0.13108103 -0.09720321]
